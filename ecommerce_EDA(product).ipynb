# %%
import pandas as pd

# %%
product_og = pd.read_csv('Product.csv')

# %%
product_og.isnull().sum()
# Out:
# CLNT_ID      2
# SESS_ID      0
# HITS_SEQ     1
# PD_C         1
# PD_ADD_NM    1
# PD_BRA_NM    1
# PD_BUY_AM    1
# PD_BUY_CT    1
# dtype: int64

# %%
product = product.dropna(axis=0)

# %%
product.isnull().sum()
# Out:
# CLNT_ID      0
# SESS_ID      0
# HITS_SEQ     0
# PD_C         0
# PD_ADD_NM    0
# PD_BRA_NM    0
# PD_BUY_AM    0
# PD_BUY_CT    0
# dtype: int64

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1048574 entries, 0 to 1048575
# Data columns (total 8 columns):
# CLNT_ID      1048574 non-null float64
# SESS_ID      1048574 non-null int64
# HITS_SEQ     1048574 non-null float64
# PD_C         1048574 non-null float64
# PD_ADD_NM    1048574 non-null object
# PD_BRA_NM    1048574 non-null object
# PD_BUY_AM    1048574 non-null float64
# PD_BUY_CT    1048574 non-null float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 72.0+ MB

# %%
product.head(10)
# Out:
#      CLNT_ID   SESS_ID  HITS_SEQ      PD_C                         PD_ADD_NM  \
# 0  4139680.0   7605037      12.0  642112.0                           색상:워터멜론
# 1  4140076.0  10189797      13.0  570603.0  색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개
# 2  4142395.0   6158159      85.0  179538.0                         (not set)
# 3  4144914.0   7935714      12.0  554336.0      색상:블랙|사이즈:160cm(12~13세) / 1개
# 4  4144917.0   6406509      78.0  190306.0                                5개
# 5  4147643.0   4050743      66.0  149995.0            사이즈:옵션04.AN868_04 / 1개
# 6  4147739.0   6881895      10.0  568751.0             신발색상:블랙(BK)/신발사이즈:280
# 7  4148106.0   6537318      21.0  570603.0  색상:BLK0_(BLK0)BLACK|사이즈:115 / 1개
# 8  4148129.0   3942102       2.0  755148.0                     모델명:올나이터 / 1개
# 9  4148527.0   5718021      19.0  608620.0                        사이즈:7 / 1개
#
#   PD_BRA_NM  PD_BUY_AM  PD_BUY_CT
# 0   [바비브라운]    39000.0        1.0
# 1       데상트    39000.0        2.0
# ...

# %%
product_1=product.sort_values(by = ['CLNT_ID','SESS_ID','HITS_SEQ','PD_C'])

# %%
product_1.head(10)
# Out:
#          CLNT_ID   SESS_ID  HITS_SEQ      PD_C               PD_ADD_NM  \
# 56434       25.0   5317297       8.0  598634.0  피테로마 때박살:피테로마 때박살 120종
# 728477      25.0   6059256       8.0  715072.0               (not set)
# 661185      33.0  10548225      13.0  605825.0               (not set)
# 531997      56.0   2108568      57.0  425529.0         선택:데일리 디펜스 / 1개
# 531998      56.0   2108568      57.0  425529.0             선택:딥모이 / 1개
# 612618      59.0    425903      13.0  677311.0                      2개
# 364767      68.0   4237632      31.0  157467.0     색상:루쥬 알뤼르 N0.1 / 1개
# 982211      71.0   4825972      12.0  184851.0             사이즈:66 / 1개
# 689675     121.0   9630270      45.0  576541.0    사이즈:230-235[W6] / 1개
# 1010096    135.0    253618      21.0   96680.0  색상:794그레이|사이즈:230 / 1개
#
#         PD_BRA_NM  PD_BUY_AM  PD_BUY_CT
# 56434       [유씨지]    39800.0        1.0
# 728477       [이롬]    47000.0        1.0
# 661185     [슈에무라]    49000.0        1.0
# ...

# %%
product.describe()
# Out:
#             CLNT_ID       SESS_ID      HITS_SEQ          PD_C     PD_BUY_AM  \
# count  1.048574e+06  1.048574e+06  1.048574e+06  1.048574e+06  1.048574e+06
# mean   3.323787e+06  5.828583e+06  7.951618e+01  4.880522e+05  2.461276e+04
# std    1.917232e+06  3.071104e+06  8.425344e+01  2.492735e+05  2.076015e+04
# min    2.500000e+01  2.600000e+01  1.000000e+00  4.000000e+00  1.000000e+01
# 25%    1.656017e+06  3.242700e+06  2.400000e+01  2.789090e+05  4.200000e+03
# 50%    3.337207e+06  6.019550e+06  4.900000e+01  5.137340e+05  7.000000e+03
# 75%    4.994410e+06  8.428752e+06  1.020000e+02  7.188360e+05  4.500000e+04
# max    6.592554e+06  1.097790e+07  5.000000e+02  8.476520e+05  5.530000e+04
#
#           PD_BUY_CT
# count  1.048574e+06
# mean   1.521181e+00
# std    6.471342e+00
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    1.440000e+03

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#히스토그램
plt.hist(product['PD_BUY_AM'], rwidth=0.9)
plt.xlabel('X')
plt.ylabel('frequency')
plt.show()

# %%
#히스토그램
plt.hist(product['PD_BUY_CT'], rwidth=0.9)
plt.xlabel('X')
plt.ylabel('frequency')
plt.show()

# %%
sns.relplot(x='PD_BUY_AM', y='PD_BUY_CT', data = product_1)
plt.show()

# %%
session = pd.read_csv('Session.csv')

# %%
session
# Out:
#          CLNT_ID   SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT TOT_SESS_HR_V  \
# 0        5873599   8641867         9  20180509             82.0         1,890
# 1        5873599   6616320        21  20180611            105.0         1,604
# 2        5873599   5886172        40  20180624             41.0           632
# 3        5873884   1050889        15  20180913            160.0         1,035
# 4        5874461  10298270         5  20180412             13.0           298
# 5        5874701    608577        65  20180920             41.0           444
# 6        5874829   1666766        87  20180903             36.0           340
# 7        5874829   1670494        86  20180903            103.0           976
# 8        5874829   1694242        85  20180902            154.0         3,099
# 9        5874829   1559438        92  20180904             24.0           317
# 10       5874900  10229983         7  20180413            207.0         4,143
# ...

# %%
session_1 = session.sort_values(by=['CLNT_ID','SESS_ID','SESS_SEQ','SESS_DT'])

# %%
session_1
# Out:
#          CLNT_ID   SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT TOT_SESS_HR_V  \
# 2126117  6592554   7240794         1  20180601             13.0         1,218
# 2302953  6592553   3241408         2  20180806             35.0         1,662
# 2302954  6592553   2537044        27  20180818             10.0           456
# 2054315  6592551   1352463       331  20180908            168.0         1,482
# 2054314  6592551   1107655       342  20180912             85.0           384
# 422943   6592544   8270794         1  20180515             13.0           105
# 2126116  6592537    386248        96  20180924             94.0         2,286
# 2126115  6592537    294554       104  20180926            290.0         6,028
# 298511   6592536   1347403        57  20180908            239.0         1,214
# 298509   6592536   1078369        62  20180912             50.0           525
# 298510   6592536     61570        67  20180930             57.0           567
# ...

# %%
pd.read_csv('Search1.csv')
# Out:
#          CLNT_ID   SESS_ID      KWD_NM  SEARCH_CNT
# 0        5607714   7112876    빌리프 아이크림           6
# 1        5607714   4090791   프리메라 마스크팩           3
# 2        5607714   4090791       여성청결제           1
# 3        5612428   1876482        명품가방           1
# 4        5612428    658123   콩순이 아이스크림           1
# 5        5612428   1876482  블루독 티셔츠 남아           1
# 6        5612471   8539312       쉬폰원피스           1
# 7        5612471   8539312  여성 쉬폰 블라우스           1
# 8        5613055   8510027      임산부 팬티           2
# 9        5613055   8510027     임산부 원피스           1
# 10       5609603  10483281       베베드피노          27
# 11       5609603  10483281         쁘띠뮤           6
# 12       5609603  10483281   베베드피노 티셔츠           2
# 13       5609763   6286724   남성 반팔 티셔츠           4
# 14       5609800   7380789    메트로시티 지갑           1
# 15       5609800  10249029   닥스 양말선물세트           1
# 16       5609800   7380789       크로커다일           2
# ...

# %%
pd.read_csv('Search2.csv')
# Out:
#           SESS_DT           KWD_NM SEARCH_CNT
# 0        20180407            닥스원피스          8
# 1        20180407        닥터지 브라이트닝          1
# 2        20180407           달팡 인트랄          2
# 3        20180407              대상트          1
# 4        20180407             더블유닷          6
# 5        20180407        더블하트 모유실감          1
# 6        20180407         데님 롱 스커트          6
# 7        20180407           데상트 크론         12
# 8        20180407          데상트골프여성          6
# 9        20180407          데상트여성골프          1
# 10       20180407         데상트여성티셔츠          2
# 11       20180407            데코뷰커튼          4
# 12       20180407              덴탈껌          1
# 13       20180407           도깨비방망이          8
# 14       20180407             도마꽂이          6
# 15       20180407             동물잠옷         31
# 16       20180407          동서가구 쇼파          1
# 17       20180407              돼지코          1
# 18       20180407               드넬          4
# ...
